# %%
#Angelehnt an: https://github.com/parth1902/Scrape-FBref-data/blob/master/README.md
#Weitere Links: https://statsbomb.com/articles/soccer/statsbomb-release-free-2020-21-fa-womens-super-league-data-updated-r-guide/

#Packete
import pandas as pd
import requests
import matplotlib.pyplot as plt
import seaborn as sns

#Scraper funktion
def scraper(url, table_number):
    #Variablen welche übergeben werden müssen
    #URL: eine FBREF URL mit einer Tabelle
    #table_number: welche Tabelle auf der Seite (startet mit 0)
    url = url
    table_number = table_number
    global data
    #Änderungen an HTML damits läuft
    #siehe: https://github.com/parth1902/Scrape-FBref-data/blob/master/README.md
    html_content = requests.get(url).text.replace('<!--', '').replace('-->', '')
    df = pd.read_html(html_content)
    #Ldf laden
    data = df[table_number]
     
    column_names = ["_".join(col) for col in data.columns.values]
    column_names = [col.replace("Unnamed: ","").replace('_level_0','') for col in column_names]
    data.columns = column_names
    # Wenn NaN Problem -> auskommentieren
    # data = data.dropna()
    data[data.columns[0]]
    if data.columns[0] == "0_Rk":
        data[data['1_Player'] != 'Player']
        del data['0_Rk']
    elif data.columns[0] == '0_Player':
        data[data['0_Player'] != 'Player']

# %%
#Variablen welche übergeben werden müssen
#URL: eine FBREF URL mit einer Tabelle (bspw. https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats)
#table_number: welche Tabelle auf der Seite (startet mit 0)

url = 'https://fbref.com/en/squads/1ebc1a5b/Atlanta-United-Stats'
table_number = 1

scraper(url, table_number)
data
# Out:
#        D_a_t_e T_i_m_e              C_o_m_p       R_o_u_n_d D_a_y V_e_n_u_e  \
# 0          NaN     NaN  Major League Soccer  Regular Season   NaN      Away
# 1   2022-02-27   15:00  Major League Soccer  Regular Season   Sun      Home
# 2   2022-03-05   16:00  Major League Soccer  Regular Season   Sat      Away
# 3   2022-03-13   16:30  Major League Soccer  Regular Season   Sun      Home
# 4   2022-03-19   16:00  Major League Soccer  Regular Season   Sat      Home
# 5   2022-04-02   19:30  Major League Soccer  Regular Season   Sat      Away
# 6   2022-04-10   13:30  Major League Soccer  Regular Season   Sun      Away
# 7   2022-04-16   18:00  Major League Soccer  Regular Season   Sat      Home
# 8   2022-04-24   13:00  Major League Soccer  Regular Season   Sun      Away
# 9   2022-05-07   18:00  Major League Soccer  Regular Season   Sat      Home
# 10  2022-05-15   14:00  Major League Soccer  Regular Season   Sun      Home
# 11  2022-05-21   18:30  Major League Soccer  Regular Season   Sat      Away
# 12  2022-05-28   19:00  Major League Soccer  Regular Season   Sat      Home
# 13  2022-06-19   16:00  Major League Soccer  Regular Season   Sun      Home
# 14  2022-06-25   19:30  Major League Soccer  Regular Season   Sat      Away
# 15  2022-06-30   20:00  Major League Soccer  Regular Season   Thu      Away
# 16  2022-07-03   17:00  Major League Soccer  Regular Season   Sun      Away
# 17  2022-07-09   19:00  Major League Soccer  Regular Season   Sat      Home
# 18  2022-07-13   19:30  Major League Soccer  Regular Season   Wed      Home
# 19  2022-07-17   15:00  Major League Soccer  Regular Season   Sun      Home
# 20  2022-07-24   18:30  Major League Soccer  Regular Season   Sun      Away
# 21  2022-07-30   16:00  Major League Soccer  Regular Season   Sat      Away
# 30         NaN  NaN  NaN      Orlando City  NaN    NaN      NaN
# 31         NaN  NaN  NaN      Philadelphia  NaN    NaN      NaN
# 32         NaN  NaN  NaN       New England  NaN    NaN      NaN
# 33         NaN  NaN  NaN             NYCFC  NaN    NaN      NaN
#
#     A_t_t_e_n_d_a_n_c_e C_a_p_t_a_i_n F_o_r_m_a_t_i_o_n   R_e_f_e_r_e_e  \
# 0                   NaN           NaN               NaN             NaN
# 1               67523.0    Brad Guzan             4-3-3       Ted Unkel
# 2                   NaN    Brad Guzan             4-3-3   Joe Dickerson
# 3               43055.0    Brad Guzan             4-3-3  Guido Gonzalez
# 4                   NaN           NaN               NaN             NaN
# 5                   NaN           NaN               NaN             NaN
# 6                   NaN           NaN               NaN             NaN
# 7                   NaN           NaN               NaN             NaN
# 8                   NaN           NaN               NaN             NaN
# 9                   NaN           NaN               NaN             NaN
# 10                  NaN           NaN               NaN             NaN
# 11                  NaN           NaN               NaN             NaN
# 12                  NaN           NaN               NaN             NaN
# 13                  NaN           NaN               NaN             NaN
# 14                  NaN           NaN               NaN             NaN
# 15                  NaN           NaN               NaN             NaN
# 16                  NaN           NaN               NaN             NaN
# 17                  NaN           NaN               NaN             NaN
# 18                  NaN           NaN               NaN             NaN
# 19                  NaN           NaN               NaN             NaN
# 20                  NaN           NaN               NaN             NaN
# 21                  NaN           NaN               NaN             NaN
# 22                  NaN           NaN               NaN             NaN
# 23                  NaN           NaN               NaN             NaN
# 24                  NaN           NaN               NaN             NaN
# 25                  NaN           NaN               NaN             NaN
# 26                  NaN           NaN               NaN             NaN
# 27                  NaN           NaN               NaN             NaN
# 28                  NaN           NaN               NaN             NaN
# 29                  NaN           NaN               NaN             NaN
# 30                  NaN           NaN               NaN             NaN
# 31                  NaN           NaN               NaN             NaN
# 32                  NaN           NaN               NaN             NaN
# 33                  NaN           NaN               NaN             NaN
#
#    M_a_t_c_h_ _R_e_p_o_r_t  N_o_t_e_s
# 0             Head-to-Head        NaN
# 1             Match Report        NaN
# 2             Match Report        NaN
# 3             Match Report        NaN
# 4             Head-to-Head        NaN
# 5             Head-to-Head        NaN
# 6             Head-to-Head        NaN
# 7             Head-to-Head        NaN
# 8             Head-to-Head        NaN
# 9             Head-to-Head        NaN
# 10            Head-to-Head        NaN
# 11            Head-to-Head        NaN
# 12            Head-to-Head        NaN
# 13            Head-to-Head        NaN
# 14            Head-to-Head        NaN
# 15            Head-to-Head        NaN
# 16            Head-to-Head        NaN
# 17            Head-to-Head        NaN
# 18            Head-to-Head        NaN
# 19            Head-to-Head        NaN
# 20            Head-to-Head        NaN
# 21            Head-to-Head        NaN
# 22            Head-to-Head        NaN
# 23            Head-to-Head        NaN
# 24            Head-to-Head        NaN
# 25            Head-to-Head        NaN
# 26            Head-to-Head        NaN
# 27            Head-to-Head        NaN
# 28            Head-to-Head        NaN
# 29            Head-to-Head        NaN
# 30            Head-to-Head        NaN
# 31            Head-to-Head        NaN
# 32            Head-to-Head        NaN
# 33            Head-to-Head        NaN
